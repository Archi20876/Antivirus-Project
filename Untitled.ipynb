# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_raw = pd.read_csv("features.csv")
df_raw.head()
# Out:
#                                  filename   entropy  size_bytes    byte_0  \
# 0  windows_x64_custom_reverse_winhttp.dll  0.370278        9216  0.716688
# 1                         benign_222.json  0.504069          49  0.000000
# 2                          benign_408.txt  0.523905          69  0.000000
# 3                           benign_213.md  0.563706          88  0.000000
# 4                          benign_319.csv  0.509960          34  0.000000
#
#      byte_1    byte_2    byte_3    byte_4    byte_5    byte_6  ...  byte_246  \
# 0  0.004666  0.001628  0.001519  0.002279  0.001411  0.001085  ...  0.000217
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...  0.000000
#
#    byte_247  byte_248  byte_249  byte_250  byte_251  byte_252  byte_253  \
# 0  0.000434  0.000326  0.000326  0.000651  0.000217  0.000326  0.000434
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#    byte_254  byte_255
# 0  0.000977  0.003581
# 1  0.000000  0.000000
# 2  0.000000  0.000000
# 3  0.000000  0.000000
# 4  0.000000  0.000000
#
# [5 rows x 259 columns]

# %%
LABELED_CSV = 'features_labeled.csv'
LABELED_CSV
# Out:
# 'features_labeled.csv'

# %%
import re

MALICIOUS_PATTERNS = [
    'meterpreter', 'shell_reverse', 'shell_bind', 'patchupmeterpreter',
    'vncinject', 'custom_reverse', 'custom_bind', 'pingback',
    'metsvc', 'adduser', 'format_all_drives', 'download_exec',
    'speak_pwned', 'messagebox', 'powershell_reverse', 'powershell_bind',
    'find_tag', 'reverse_tcp', 'bind_tcp', 'reverse_http', 'reverse_https',
    'reverse_udp', 'bind_udp', 'named_pipe', 'reverse_ord', 'bind_ord'
]
BENIGN_EXTENSIONS    = ['.txt', '.log', '.md', '.csv', '.json', '.so', '.o']
MALICIOUS_EXTENSIONS = ['.exe', '.dll', '.ps1', '.bat', '.vbs',
                         '.sys', '.scr', '.pif', '.com', '.elf', '.sh']
BENIGN_BINARY_NAMES  = [
    'ls', 'cat', 'grep', 'find', 'curl', 'wget', 'tar', 'zip',
    'gcc', 'python3', 'bash', 'sh', 'cp', 'mv', 'rm', 'chmod'
]

def auto_label(fname):
    fname_lower = fname.lower()

    # 1. Malicious by strong payload keywords ONLY
    for pat in MALICIOUS_PATTERNS:
        if pat in fname_lower:
            return 1

    # 2. Hash-named + suspicious extension → malicious
    name_only = fname_lower.rsplit('.', 1)[0]
    is_hash   = bool(re.match(r'^[0-9a-f]{32,}$', name_only))
    if is_hash:
        for ext in MALICIOUS_EXTENSIONS:
            if fname_lower.endswith(ext):
                return 1

    # 3. Known system binaries → benign
    if fname_lower in BENIGN_BINARY_NAMES:
        return 0

    # ❗ DO NOT auto-label benign by extension anymore
    return -1

# Apply
df = df_raw.copy()
df['label'] = df['filename'].apply(auto_label)
df['label'] = df['label'].replace(-1, 0)

print('Label distribution:')
print(df['label'].value_counts().rename({0:'Benign', 1:'Malicious', -1:'Unknown'}))


df.to_csv(LABELED_CSV, index=False)

print(f"Labeled CSV saved as: {LABELED_CSV}")
# Out:
# Label distribution:
# label
# Benign       510
# Malicious    499
# Name: count, dtype: int64
# Labeled CSV saved as: features_labeled.csv

# %%
df = df_raw.copy()
df['label'] = df['filename'].apply(auto_label)

# %%
# Check what the 43 unknown filenames actually look like
unknown = df[df['label'] == -1][['filename']]
print(f"Total unknowns: {len(unknown)}")
print(unknown.to_string())
# Out:
# Total unknowns: 501
#              filename
# 1     benign_222.json
# 2      benign_408.txt
# 3       benign_213.md
# 4      benign_319.csv
# 5       benign_232.md
# 6       benign_62.csv
# 9       benign_14.txt
# 12      benign_60.log
# 14     benign_216.log
# 15     benign_291.txt
# 16     benign_448.log
# 17       benign_6.log
# 18    benign_494.json
# 19     benign_493.txt
# 20     benign_376.csv
# 23     benign_456.csv
# 24       failures.log
# 25     benign_340.csv
# 26      benign_64.log
# 28     benign_171.txt
# 30       benign_46.md
# 32    benign_221.json
# 34      benign_259.md
# 39      benign_2.json
# 42      benign_71.txt
# 51    benign_276.json
# 52     benign_434.csv
# 53     benign_86.json
# 55      benign_127.md
# 56    benign_103.json
# 59     benign_50.json
# 60    benign_489.json
# 61     benign_37.json
# 63     benign_349.txt
# 64     benign_286.txt
# 66     benign_343.txt
# 72      benign_30.txt
# 75      benign_117.md
# 76     benign_306.csv
# 78     benign_482.txt
# 79      benign_439.md
# 83     benign_126.log
# 86      benign_24.log
# 87       benign_42.md
# 88       benign_85.md
# 89      benign_239.md
# 90    benign_385.json
# 91    benign_148.json
# 92    benign_430.json
# 93     benign_178.csv
# 95      benign_72.csv
# 96     benign_495.log
# 97      benign_17.csv
# 98     benign_262.log
# 102     benign_237.md
# 103    benign_484.txt
# 105    benign_432.txt
# 106    benign_152.txt
# 111   benign_302.json
# 114   benign_409.json
# 117     benign_115.md
# 118     benign_311.md
# 119   benign_138.json
# 122    benign_309.log
# 124    benign_131.txt
# 128   benign_240.json
# 130    benign_421.log
# 131     benign_76.txt
# 134     benign_203.md
# 136    benign_235.csv
# 138   benign_404.json
# 139    benign_396.csv
# 140    benign_446.log
# 143    benign_315.csv
# 147   benign_336.json
# 150    benign_288.txt
# 155    benign_250.txt
# 156   benign_359.json
# 158    benign_420.csv
# 159     benign_80.csv
# 161     benign_10.csv
# 165      benign_75.md
# 166     benign_480.md
# 167    benign_368.txt
# 170    benign_498.txt
# 172    benign_20.json
# 173    benign_251.csv
# 176   benign_116.json
# 177    benign_170.log
# 178     benign_161.md
# 179   benign_258.json
# 180    benign_114.txt
# 185     benign_59.csv
# 188     benign_34.txt
# 189     benign_358.md
# 191    benign_283.txt
# 192    benign_338.csv
# 193    benign_236.log
# 196     benign_499.md
# 197    benign_418.csv
# 198    benign_478.log
# 199    benign_112.log
# 200    benign_339.log
# 202    benign_97.json
# 203     benign_61.log
# 209    benign_411.csv
# 211     benign_38.log
# 213   benign_130.json
# 216     benign_173.md
# 217    benign_120.log
# 223   benign_375.json
# 224     benign_118.md
# 228    benign_225.csv
# 229    benign_474.log
# 230    benign_281.txt
# 233     benign_211.md
# 237    benign_218.txt
# 238    benign_415.log
# 239      benign_57.md
# 247    benign_314.log
# 248    benign_177.csv
# 249     benign_487.md
# 253   benign_244.json
# 255    benign_67.json
# 256     benign_183.md
# 257    benign_317.log
# 258   benign_374.json
# 260    benign_205.csv
# 261    benign_373.csv
# 264     benign_417.md
# 267     benign_101.md
# 268    benign_433.log
# 270   benign_450.json
# 271    benign_79.json
# 276    benign_459.log
# 278    benign_451.txt
# 279    benign_196.txt
# 280    benign_322.txt
# 283   benign_383.json
# 284    benign_469.txt
# 286     benign_95.txt
# 288     benign_12.log
# 289    benign_214.log
# 290    benign_146.txt
# 291    benign_249.csv
# 297      benign_91.md
# 298    benign_443.csv
# 299    benign_199.csv
# 300    benign_141.txt
# 301      benign_31.md
# 302     benign_77.csv
# 303     benign_208.md
# 304     benign_200.md
# 307    benign_124.log
# 311   benign_266.json
# 312   benign_136.json
# 313   benign_332.json
# 314    benign_254.txt
# 315    benign_295.txt
# 316   benign_267.json
# 320   benign_245.json
# 323     benign_3.json
# 324     benign_35.txt
# 325     benign_371.md
# 326     benign_88.csv
# 330   benign_454.json
# 332     benign_394.md
# 333     benign_360.md
# 336   benign_123.json
# 341    benign_248.csv
# 342     benign_457.md
# 344   benign_298.json
# 345    benign_384.csv
# 346     benign_253.md
# 348       benign_5.md
# 349     benign_147.md
# 350    benign_405.txt
# 351    benign_272.txt
# 352    benign_163.txt
# 354    benign_223.log
# 357    benign_29.json
# 358    benign_246.csv
# 359    benign_48.json
# 362    benign_228.log
# 363   benign_279.json
# 364     benign_488.md
# 365    benign_380.log
# 366    benign_53.json
# 367    benign_496.csv
# 368    benign_440.csv
# 369    benign_327.txt
# 370    benign_320.csv
# 372   benign_363.json
# 374    benign_331.txt
# 380    benign_215.csv
# 381      benign_9.csv
# 383     benign_265.md
# 387     benign_194.md
# 390    benign_428.csv
# 394     benign_92.log
# 395    benign_458.txt
# 396     benign_22.csv
# 398    benign_490.log
# 401    benign_470.csv
# 402      benign_13.md
# 403     benign_406.md
# 408   benign_348.json
# 410    benign_378.csv
# 412   benign_387.json
# 414     benign_1.json
# 416   benign_365.json
# 417     benign_425.md
# 419    benign_437.log
# 421    benign_233.log
# 423   benign_176.json
# 424    benign_166.log
# 426    benign_139.txt
# 427   benign_442.json
# 429     benign_329.md
# 431     benign_449.md
# 432    benign_135.txt
# 433   benign_471.json
# 435     benign_21.txt
# 436    benign_491.log
# 439    benign_397.csv
# 441      benign_36.md
# 443     benign_87.log
# 446    benign_226.csv
# 447   benign_463.json
# 448    benign_429.txt
# 454     benign_323.md
# 458    benign_271.txt
# 460     benign_413.md
# 461   benign_436.json
# 464     benign_47.log
# 470    benign_156.csv
# 471    benign_330.log
# 472     benign_132.md
# 473    benign_268.log
# 475    benign_150.log
# 476    benign_282.log
# 477     benign_96.log
# 478    benign_423.log
# 479    benign_197.log
# 484      benign_8.csv
# 485    benign_227.log
# 487    benign_149.csv
# 488     benign_354.md
# 493   benign_377.json
# 494    benign_366.csv
# 497    benign_481.csv
# 499     benign_400.md
# 500    benign_422.txt
# 503     benign_58.log
# 505    benign_292.log
# 507    benign_111.csv
# 508     benign_44.csv
# 509      benign_7.txt
# 510    benign_447.csv
# 511      benign_23.md
# 512     benign_342.md
# 515   benign_344.json
# 516    benign_294.log
# 517    benign_119.log
# 519    benign_500.log
# 520    benign_312.txt
# 522    benign_174.csv
# 524     benign_81.log
# 526    benign_172.txt
# 529    benign_303.txt
# 530    benign_485.txt
# 532    benign_390.log
# 533    benign_424.csv
# 534      benign_98.md
# 535    benign_300.csv
# 536     benign_145.md
# 539    benign_280.log
# 540      benign_27.md
# 541     benign_93.csv
# 544     benign_51.txt
# 545    benign_204.log
# 551    benign_252.txt
# 555      benign_41.md
# 556    benign_274.csv
# 558    benign_192.txt
# 561     benign_78.csv
# 563     benign_73.log
# 564    benign_299.csv
# 565    benign_193.txt
# 566     benign_168.md
# 569   benign_137.json
# 570      benign_40.md
# 574    benign_151.txt
# 575    benign_334.log
# 578    benign_321.log
# 582    benign_207.txt
# 583   benign_182.json
# 585     benign_333.md
# 588   benign_220.json
# 589    benign_187.log
# 590    benign_159.log
# 592    benign_318.log
# 595   benign_441.json
# 596    benign_109.log
# 597    benign_438.csv
# 598    benign_473.csv
# 602    benign_479.log
# 605    benign_361.txt
# 606     benign_351.md
# 608    benign_89.json
# 612   benign_308.json
# 614     benign_65.csv
# 616   benign_497.json
# 621   benign_465.json
# 627     benign_270.md
# 628    benign_370.log
# 630    benign_369.txt
# 633   benign_427.json
# 636     benign_74.log
# 638    benign_492.csv
# 639    benign_108.csv
# 640    benign_313.txt
# 642    benign_285.log
# 644     benign_94.txt
# 645    benign_352.log
# 649   benign_247.json
# 650   benign_466.json
# 656     benign_25.log
# 657     benign_129.md
# 658    benign_264.csv
# 659    benign_372.txt
# 660     benign_56.csv
# 661    benign_158.txt
# 663     benign_122.md
# 665    benign_356.txt
# 668     benign_256.md
# 669    benign_350.txt
# 675    benign_324.txt
# 676     benign_435.md
# 679    benign_84.json
# 682      benign_4.csv
# 684      benign_69.md
# 687     benign_347.md
# 689   benign_230.json
# 690    benign_461.txt
# 695    benign_257.txt
# 696    benign_486.log
# 698    benign_238.csv
# 700   benign_316.json
# 701     benign_462.md
# 702    benign_407.txt
# 703    benign_453.csv
# 707     benign_305.md
# 711     benign_290.md
# 718     benign_104.md
# 719    benign_175.txt
# 725    benign_206.log
# 726   benign_260.json
# 727     benign_219.md
# 729     benign_431.md
# 731    benign_386.txt
# 732     benign_45.txt
# 733    benign_345.log
# 734    benign_297.txt
# 735    benign_367.log
# 736    benign_275.txt
# 737     benign_393.md
# 738    benign_346.csv
# 740    benign_99.json
# 741   benign_155.json
# 743    benign_289.txt
# 744    benign_128.txt
# 745    benign_154.txt
# 747   benign_296.json
# 750    benign_243.txt
# 752    benign_102.log
# 753   benign_483.json
# 754    benign_401.log
# 757    benign_153.csv
# 758    benign_125.log
# 760    benign_398.log
# 762   benign_134.json
# 764    benign_181.csv
# 770    benign_269.log
# 772     benign_475.md
# 775     benign_82.log
# 776    benign_391.csv
# 778     benign_261.md
# 779    benign_341.csv
# 781   benign_382.json
# 786    benign_142.csv
# 789    benign_467.log
# 791    benign_273.txt
# 792    benign_100.txt
# 797    benign_186.txt
# 798     benign_19.csv
# 801    benign_140.log
# 802    benign_144.csv
# 806     benign_476.md
# 810    benign_277.log
# 812   benign_326.json
# 813    benign_455.csv
# 816    benign_416.txt
# 817     benign_179.md
# 821    benign_165.log
# 822     benign_26.txt
# 825    benign_307.csv
# 826   benign_191.json
# 827    benign_468.txt
# 828    benign_83.json
# 831     benign_241.md
# 832    benign_402.csv
# 839     benign_11.csv
# 840    benign_202.log
# 842    benign_395.log
# 846     benign_293.md
# 847     benign_414.md
# 848    benign_399.log
# 849     benign_54.csv
# 850    benign_113.csv
# 851     benign_90.txt
# 853    benign_477.csv
# 854     benign_32.txt
# 856     benign_362.md
# 858     benign_224.md
# 859    benign_188.csv
# 862    benign_412.log
# 863     benign_66.csv
# 864     benign_304.md
# 865    benign_445.txt
# 869    benign_229.txt
# 870    benign_234.txt
# 871   benign_379.json
# 872     benign_33.txt
# 873    benign_143.log
# 875    benign_68.json
# 877     benign_335.md
# 878    benign_357.log
# 880    benign_310.log
# 881    benign_212.txt
# 882   benign_105.json
# 887    benign_328.csv
# 896    benign_184.log
# 901   benign_388.json
# 902    benign_162.log
# 903     benign_364.md
# 905    benign_107.csv
# 906    benign_169.txt
# 908     benign_392.md
# 909     benign_419.md
# 910     benign_190.md
# 911    benign_70.json
# 912    benign_160.log
# 913     benign_133.md
# 914    benign_284.csv
# 915   benign_278.json
# 919    benign_198.csv
# 922    benign_28.json
# 923     benign_444.md
# 924    benign_242.txt
# 925     benign_464.md
# 927    benign_389.csv
# 928    benign_301.txt
# 930      benign_55.md
# 931    benign_217.log
# 934    benign_209.txt
# 938     benign_255.md
# 939     benign_201.md
# 940     benign_353.md
# 942    benign_164.csv
# 944    benign_403.txt
# 945    benign_410.log
# 946    benign_460.log
# 950     benign_49.csv
# 957     benign_325.md
# 958      benign_18.md
# 960     benign_43.csv
# 961     benign_185.md
# 962    benign_189.log
# 963    benign_180.log
# 965   benign_287.json
# 967    benign_426.txt
# 970    benign_110.csv
# 973     benign_16.txt
# 976     benign_63.txt
# 980    benign_381.txt
# 983    benign_263.csv
# 984    benign_121.txt
# 986     benign_15.txt
# 988    benign_452.log
# 991    benign_195.log
# 992     benign_39.log
# 993    benign_472.log
# 994    benign_355.csv
# 995     benign_52.txt
# 997    benign_157.log
# 998    benign_210.csv
# 1002   benign_337.csv
# 1005  benign_231.json
# 1007    benign_106.md
# 1008  benign_167.json

# %%
df_clean = df.copy()

# Convert unknown → benign
df_clean['label'] = df_clean['label'].replace(-1, 0)

print(f'Training samples: {len(df_clean)} (including unknowns as benign)')
# Out:
# Training samples: 1009 (including unknowns as benign)

# %%
DROP_COLS = ['filename', 'label']
X = df_clean.drop(columns=DROP_COLS)
y = df_clean['label']

# %%
counts = y.value_counts()
ratio  = counts.min() / counts.max()
print(f'\nClass balance — Benign: {counts[0]}  |  Malicious: {counts[1]}')
if ratio < 0.3:
    print('⚠ Class imbalance detected — models will use class_weight="balanced"')
print(f'Feature matrix: {X.shape[0]} rows × {X.shape[1]} features')
# Out:
# Class balance — Benign: 510  |  Malicious: 499
# Feature matrix: 1009 rows × 258 features

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    random_state=42,
    stratify=y          # keeps class ratio the same in train & test
)
print(f'Train: {len(X_train)}  |  Test: {len(X_test)}')
# Out:
# Train: 756  |  Test: 253

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import (
    classification_report, accuracy_score, roc_auc_score,
    confusion_matrix, ConfusionMatrixDisplay
)
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
                  

import joblib

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scale_pos_weight = float(np.sum(y_train == 0)) / max(float(np.sum(y_train == 1)), 1)

models = {
    'Random Forest': RandomForestClassifier(
        n_estimators=200, class_weight='balanced', random_state=42, n_jobs=-1),
    'Extra Trees': ExtraTreesClassifier(
        n_estimators=200, class_weight='balanced', random_state=42, n_jobs=-1),
    'Gradient Boosting': GradientBoostingClassifier(
        n_estimators=150, learning_rate=0.1, max_depth=4, random_state=42),
    'XGBoost': XGBClassifier(
        n_estimators=300, learning_rate=0.05, max_depth=6,
        scale_pos_weight=scale_pos_weight, eval_metric='logloss',
        random_state=42, n_jobs=-1),
}

# %%
results = {}
print(f'{"Model":<25} {"CV Acc (mean)":>15} {"CV Acc (std)":>14} {"CV F1":>10}')
print('-' * 68)
for name, model in models.items():
    cv_acc = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy', n_jobs=-1)
    cv_f1  = cross_val_score(model, X_train, y_train, cv=cv, scoring='f1', n_jobs=-1)
    results[name] = {'cv_acc_mean': cv_acc.mean(), 'cv_acc_std': cv_acc.std(), 'cv_f1_mean': cv_f1.mean()}
    print(f'{name:<25} {cv_acc.mean():>14.4f} {cv_acc.std():>14.4f} {cv_f1.mean():>10.4f}')

print('\n✓ Cross-validation complete')
# Out:
# Model                       CV Acc (mean)   CV Acc (std)      CV F1
# --------------------------------------------------------------------
# Random Forest                     0.9960         0.0053     0.9960
# Extra Trees                       0.9974         0.0032     0.9973
# Gradient Boosting                 0.9934         0.0073     0.9933
# XGBoost                           0.9947         0.0077     0.9947
#
# ✓ Cross-validation complete

# %%
from sklearn.utils import shuffle

y_random = shuffle(y_train, random_state=42)
random_scores = cross_val_score(
    models['Extra Trees'], X_train, y_random, cv=cv, scoring='f1', n_jobs=-1
)
print(f"Random label F1: {random_scores.mean():.4f}")
# Out:
# Random label F1: 0.4913

# %% [markdown]
# checking if rf is overfitting or not ,if your model shows Random label F1: 0.9100   ← still overfitting, features are leaking the label.   OR
# if it shows Random label F1: 0.4823   ← model is working correctly, data is genuinely separable.

# %%
best_name = 'Random Forest'  #i will use rf as its already written in literature survey.
best_model=models[best_name]
best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

# %%
print(f'\nTest Accuracy : {accuracy_score(y_test, y_pred):.4f}')
try:
    prob = best_model.predict_proba(X_test)[:, 1]
    print(f'Test ROC-AUC  : {roc_auc_score(y_test, prob):.4f}')
except Exception:
    pass

print('\nClassification Report:')
print(classification_report(y_test, y_pred, target_names=['Benign', 'Malicious']))
# Out:
# Test Accuracy : 1.0000
# Test ROC-AUC  : 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       1.00      1.00      1.00       128
#    Malicious       1.00      1.00      1.00       125
#
#     accuracy                           1.00       253
#    macro avg       1.00      1.00      1.00       253
# weighted avg       1.00      1.00      1.00       253

# %% [markdown]
# ### 🚨 So why still 100% accuracy?
#
# Because your data is like:
#
# Benign	Malicious
# .txt, .json, .csv	payload binaries
# low entropy	high entropy
# simple structure	complex shellcode
#
# 👉 These are naturally VERY different
#
# So model learns:
#
# “clear boundary” → perfect classification
# 📊 This is called
#
# 👉 High class separability
#
# NOT:
#
# overfitting ❌
# leakage ❌

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
X_shuffled = shuffle(X_train, random_state=42)

scores = cross_val_score(
    models['Random Forest'], X_shuffled, y_train, cv=cv, scoring='f1'
)

print("Shuffled feature F1:", scores.mean())
# Out:
# Shuffled feature F1: 0.481959956878821

# %%
print("Benign entropy stats:")
print(df_clean[df_clean['label']==0]['entropy'].describe())
# Out:
# Benign entropy stats:
# count    510.000000
# mean       0.546293
# std        0.043888
# min        0.464214
# 25%        0.517932
# 50%        0.526764
# 75%        0.563706
# max        0.819311
# Name: entropy, dtype: float64

# %%
print("\nMalicious entropy stats:")
print(df_clean[df_clean['label']==1]['entropy'].describe())
# Out:
# Malicious entropy stats:
# count    499.000000
# mean       0.521467
# std        0.238577
# min        0.043133
# 25%        0.280206
# 50%        0.555847
# 75%        0.790425
# max        0.999860
# Name: entropy, dtype: float64

# %%
import joblib

MODEL_PATH = 'antivirus_model.pkl'

# 1️⃣ Select your final model
final_model = best_model   # or ensemble if you selected it
final_name  = best_name

# 2️⃣ Train on full data
final_model.fit(X_train, y_train)

# 3️⃣ Save model
joblib.dump(final_model, MODEL_PATH)

# 4️⃣ Save feature names (VERY IMPORTANT)
joblib.dump(list(X.columns), 'feature_names.pkl')

print(f'✅ Antivirus model saved → {MODEL_PATH}')
print('✅ Feature names saved → feature_names.pkl')
# Out:
# ✅ Antivirus model saved → antivirus_model.pkl
# ✅ Feature names saved → feature_names.pkl
